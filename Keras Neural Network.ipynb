# %% [markdown]
# # A. Build a baseline model
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the train_test_split helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.

# %%
import pandas as pd
import numpy as np
concrete_data = pd.read_csv('https://cocl.us/concrete_data')
concrete_data_columns = concrete_data.columns
concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
features = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] 
print(features)
# Out:
#       Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0      540.0                 0.0      0.0  162.0               2.5
# 1      540.0                 0.0      0.0  162.0               2.5
# 2      332.5               142.5      0.0  228.0               0.0
# 3      332.5               142.5      0.0  228.0               0.0
# 4      198.6               132.4      0.0  192.0               0.0
# 5      266.0               114.0      0.0  228.0               0.0
# 6      380.0                95.0      0.0  228.0               0.0
# 7      380.0                95.0      0.0  228.0               0.0
# 8      266.0               114.0      0.0  228.0               0.0
# 9      475.0                 0.0      0.0  228.0               0.0
# 10     198.6               132.4      0.0  192.0               0.0
# 11     198.6               132.4      0.0  192.0               0.0
# 12     427.5                47.5      0.0  228.0               0.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import mean_squared_error
def regression_model():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

mean_squared_errors = []
for i in range(50):
    train_features, test_features, train_target, test_target = train_test_split(features, target, test_size=0.3)
    n_cols = train_features.shape[1]
    model = regression_model()
    model.fit(train_features, train_target, epochs=50)
    pred_target = model.predict(test_features)
    mean_squared_errors.append(mean_squared_error(test_target,pred_target))
# Out:
# Epoch 1/50
# 721/721 [==============================] - 1s 1ms/step - loss: 33960.8972
# Epoch 2/50
# 721/721 [==============================] - 0s 145us/step - loss: 10761.0435
# Epoch 3/50
# 721/721 [==============================] - 0s 213us/step - loss: 4587.4003
# Epoch 4/50
# 721/721 [==============================] - 0s 141us/step - loss: 3754.5742
# Epoch 5/50
# 721/721 [==============================] - 0s 163us/step - loss: 3265.3860
# Epoch 6/50
# 721/721 [==============================] - 0s 168us/step - loss: 2855.8867
# Epoch 7/50
# 721/721 [==============================] - 0s 193us/step - loss: 2497.4629
# Epoch 8/50
# 721/721 [==============================] - 0s 162us/step - loss: 2182.8767
# Epoch 9/50
# 721/721 [==============================] - 0s 167us/step - loss: 1914.2665
# Epoch 10/50
# 721/721 [==============================] - 0s 163us/step - loss: 1670.2304
# Epoch 11/50
# 721/721 [==============================] - 0s 145us/step - loss: 1470.0275
# ...

# %%
print('mean:', np.mean(mean_squared_errors))
print('standard deviation:', np.std(mean_squared_errors))
# Out:
# mean: 306.6814056336909
# standard deviation: 286.70578373383694

# %% [markdown]
# B. Normalize the data (5 marks)
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %%
features_norm = (features - features.mean()) / features.std()
mean_squared_errors = []
for i in range(50):
    print(i)
    train_features, test_features, train_target, test_target = train_test_split(features_norm, target, test_size=0.3)
    n_cols = train_features.shape[1]
    model = regression_model()
    model.fit(train_features, train_target, epochs=50)
    pred_target = model.predict(test_features)
    mean_squared_errors.append(mean_squared_error(test_target,pred_target))
# Out:
# 0
# Epoch 1/50
# 721/721 [==============================] - 7s 10ms/step - loss: 1556.1487
# Epoch 2/50
# 721/721 [==============================] - 0s 257us/step - loss: 1541.4347
# Epoch 3/50
# 721/721 [==============================] - 0s 197us/step - loss: 1526.1828
# Epoch 4/50
# 721/721 [==============================] - 0s 197us/step - loss: 1510.9681
# Epoch 5/50
# 721/721 [==============================] - 0s 189us/step - loss: 1495.0940
# Epoch 6/50
# 721/721 [==============================] - 0s 183us/step - loss: 1479.0014
# Epoch 7/50
# 721/721 [==============================] - 0s 203us/step - loss: 1462.1097
# Epoch 8/50
# 721/721 [==============================] - 0s 190us/step - loss: 1444.4516
# Epoch 9/50
# 721/721 [==============================] - 0s 183us/step - loss: 1425.9158
# Epoch 10/50
# 721/721 [==============================] - 0s 185us/step - loss: 1406.2928
# Epoch 11/50
# 721/721 [==============================] - 0s 199us/step - loss: 1385.5786
# ...

# %%
print('mean:', np.mean(mean_squared_errors))
print('standard deviation:', np.std(mean_squared_errors))
# Out:
# mean: 367.31954241186
# standard deviation: 86.59527164190291

# %% [markdown]
# # Answer: the mean of the mean squared error in step B is greater than that of step A

# %% [markdown]
# C. Increate the number of epochs (5 marks)
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
features_norm = (features - features.mean()) / features.std()
mean_squared_errors = []
for i in range(50):
    print(i)
    train_features, test_features, train_target, test_target = train_test_split(features_norm, target, test_size=0.3)
    n_cols = train_features.shape[1]
    model = regression_model()
    model.fit(train_features, train_target, epochs=100)
    pred_target = model.predict(test_features)
    mean_squared_errors.append(mean_squared_error(test_target,pred_target))
# Out:
# 0
# Epoch 1/100
# 721/721 [==============================] - 11s 15ms/step - loss: 1610.1276
# Epoch 2/100
# 721/721 [==============================] - 0s 193us/step - loss: 1592.1062
# Epoch 3/100
# 721/721 [==============================] - 0s 202us/step - loss: 1574.1903
# Epoch 4/100
# 721/721 [==============================] - 0s 218us/step - loss: 1556.2313
# Epoch 5/100
# 721/721 [==============================] - 0s 195us/step - loss: 1538.0136
# Epoch 6/100
# 721/721 [==============================] - 0s 220us/step - loss: 1519.8841
# Epoch 7/100
# 721/721 [==============================] - 0s 230us/step - loss: 1500.8787
# Epoch 8/100
# 721/721 [==============================] - 0s 210us/step - loss: 1481.6982
# Epoch 9/100
# 721/721 [==============================] - 0s 298us/step - loss: 1461.1920
# Epoch 10/100
# 721/721 [==============================] - 0s 221us/step - loss: 1440.1479
# Epoch 11/100
# ...

# %%
print('mean:', np.mean(mean_squared_errors))
print('standard deviation:', np.std(mean_squared_errors))
# Out:
# mean: 162.08578197565035
# standard deviation: 17.92956919160796

# %% [markdown]
# # Answer: The mean of the mean squared error in problem C is less than half of that from step B

# %% [markdown]
# D. Increase the number of hidden layers (5 marks)
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
features_norm = (features - features.mean()) / features.std()
mean_squared_errors = []
def regression_model():
    model = Sequential()
    model.add(Dense(10, activation='relu', input_shape=(n_cols,)))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model
for i in range(50):
    train_features, test_features, train_target, test_target = train_test_split(features_norm, target, test_size=0.3)
    n_cols = train_features.shape[1]
    model = regression_model()
    model.fit(train_features, train_target, epochs=50)
    pred_target = model.predict(test_features)
    mean_squared_errors.append(mean_squared_error(test_target,pred_target))
# Out:
# Epoch 1/50
# 721/721 [==============================] - 15s 21ms/step - loss: 1544.9181
# Epoch 2/50
# 721/721 [==============================] - 0s 494us/step - loss: 1523.2040
# Epoch 3/50
# 721/721 [==============================] - 0s 537us/step - loss: 1495.2301
# Epoch 4/50
# 721/721 [==============================] - 0s 520us/step - loss: 1449.9544
# Epoch 5/50
# 721/721 [==============================] - 0s 475us/step - loss: 1370.4880
# Epoch 6/50
# 721/721 [==============================] - 0s 463us/step - loss: 1238.1897
# Epoch 7/50
# 721/721 [==============================] - 1s 864us/step - loss: 1049.6501
# Epoch 8/50
# 721/721 [==============================] - 0s 493us/step - loss: 807.5449
# Epoch 9/50
# 721/721 [==============================] - 0s 552us/step - loss: 554.0006
# Epoch 10/50
# 721/721 [==============================] - 0s 496us/step - loss: 369.0294
# Epoch 11/50
# 721/721 [==============================] - 0s 525us/step - loss: 281.5385
# ...

# %%
print('mean:', np.mean(mean_squared_errors))
print('standard deviation:', np.std(mean_squared_errors))
# Out:
# mean: 128.60355877954024
# standard deviation: 16.38283021920015

# %% [markdown]
# # Answer: The mean of the mean squared error in step D is smaller than that from step B
